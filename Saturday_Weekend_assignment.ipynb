# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('cars_test.xlsx')
data
# Out:
#     symboling  normalized.losses           make fuel.type aspiration  \
# 0           3                NaN    alfa-romero       gas        std
# 1           2              164.0           audi       gas        std
# 2           2                NaN           audi       gas        std
# 3           1                NaN           audi       gas        std
# 4           1              158.0           audi       gas      turbo
# 5           2              192.0            bmw       gas        std
# 6           0                NaN            bmw       gas        std
# 7           1              118.0          dodge       gas        std
# 8           1              118.0          dodge       gas        std
# 9           1              118.0          dodge       gas      turbo
# 10          1              148.0          dodge       gas        std
# 11          1              148.0          dodge       gas      turbo
# 12         -1              110.0          dodge       gas        std
# 13          0               85.0          honda       gas        std
# 14          1                NaN          isuzu       gas        std
# 15          1              104.0          mazda       gas        std
# 16          3              150.0          mazda       gas        std
# 17          1              129.0          mazda       gas        std
# 18          0              115.0          mazda       gas        std
# 19          0              115.0          mazda       gas        std
# 20         -1               93.0  mercedes-benz    diesel      turbo
# 21         -1                NaN  mercedes-benz       gas        std
# 22          1                NaN  mercedes-benz       gas        std
# 23          1                NaN        mercury       gas      turbo
# 24          3                NaN     mitsubishi       gas      turbo
# 25          1              125.0     mitsubishi       gas      turbo
# 26          1              128.0         nissan       gas        std
# 27          2              168.0         nissan       gas        std
# 28          0              106.0         nissan       gas        std
# 29          1              231.0         nissan       gas        std
# 30          0              161.0         peugot    diesel      turbo
# 31          0                NaN         peugot       gas        std
# 32          1              154.0       plymouth       gas        std
# 33          1              154.0       plymouth       gas        std
# 34         -1               74.0       plymouth       gas        std
# 35          2              104.0           saab       gas        std
# 36          0               85.0         subaru       gas        std
# 37          0               85.0         subaru       gas      turbo
# 38          1               87.0         toyota       gas        std
# 39          0               81.0         toyota       gas        std
# 40          0               91.0         toyota    diesel        std
# 41          0               91.0         toyota       gas        std
# 42          2              134.0         toyota       gas        std
# 43         -1               65.0         toyota    diesel      turbo
# 44          2               94.0     volkswagen       gas        std
# 45          2               94.0     volkswagen    diesel      turbo
# 46          2               94.0     volkswagen       gas        std
# 47          0                NaN     volkswagen    diesel      turbo
# 48          0                NaN     volkswagen       gas        std
# 49         -1               74.0          volvo       gas        std
# 50         -1               95.0          volvo       gas        std
# 51         -1               95.0          volvo       gas      turbo
#
#    num.of.doors   body.style drive.wheels engine.location  wheel.base  ...  \
# 0           two  convertible          rwd           front        88.6  ...
# 1          four        sedan          4wd             NaN        99.4  ...
# 2           two        sedan          fwd           front        99.8  ...
# 3          four        wagon          fwd           front       105.8  ...
# 4          four        sedan          fwd           front       105.8  ...
# 5           two        sedan          rwd           front       101.2  ...
# 6          four        sedan          rwd           front       110.0  ...
# 7           two    hatchback          fwd           front        93.7  ...
# 8           two    hatchback          fwd           front        93.7  ...
# 9           two    hatchback          fwd           front        93.7  ...
# 10         four        sedan          fwd             NaN        93.7  ...
# 11          NaN        sedan          fwd           front        93.7  ...
# 12         four        wagon          fwd           front       103.3  ...
# 13         four        sedan          fwd           front        96.5  ...
# 14          two        sedan          fwd           front        94.5  ...
# 15          two    hatchback          fwd           front        93.1  ...
# 16          two    hatchback          rwd           front        95.3  ...
# 17          NaN    hatchback          fwd           front        98.8  ...
# 18          NaN        sedan          fwd           front        98.8  ...
# 19         four        sedan          fwd             NaN        98.8  ...
# 20         four        wagon          rwd           front       110.0  ...
# 21         four        sedan          rwd           front       115.6  ...
# 22          two      hardtop          rwd             NaN       112.0  ...
# 23          two    hatchback          rwd           front       102.7  ...
# 24          two    hatchback          fwd           front        95.9  ...
# 25         four        sedan          fwd           front        96.3  ...
# 26          two    hatchback          fwd           front        94.5  ...
# 27          two      hardtop          fwd           front        95.1  ...
# 28         four        sedan          fwd           front        97.2  ...
# 29          two    hatchback          rwd           front        99.2  ...
# 30          NaN        sedan          rwd           front       107.9  ...
# 31         four        wagon          rwd           front       114.2  ...
# 32         four    hatchback          fwd           front        93.7  ...
# 33         four        sedan          fwd           front        93.7  ...
# 34         four        wagon          fwd           front       103.3  ...
# 35         four        sedan          fwd           front        99.1  ...
# 36         four        wagon          4wd           front        96.9  ...
# 37         four        wagon          4wd           front        96.9  ...
# 38          two    hatchback          fwd           front        95.7  ...
# 39         four        wagon          4wd           front        95.7  ...
# 40         four    hatchback          fwd           front        95.7  ...
# 41         four        sedan          fwd           front        95.7  ...
# 42          two    hatchback          rwd           front        98.4  ...
# 43         four        sedan          fwd           front       102.4  ...
# 44         four        sedan          fwd           front        97.3  ...
# 45         four        sedan          fwd           front        97.3  ...
# 46         four        sedan          fwd           front        97.3  ...
# 47         four        sedan          fwd           front       100.4  ...
# 48          NaN        wagon          fwd           front       100.4  ...
# 49         four        wagon          rwd           front       104.3  ...
# 50         four        sedan          rwd           front       109.1  ...
# 51         four        sedan          rwd           front       109.1  ...
#
#     engine.size  fuel.system  bore  stroke compression.ratio horsepower  \
# 0           130         mpfi  3.47    2.68              9.00        111
# 1           136         mpfi  3.19    3.40              8.00        115
# 2           136         mpfi  3.19    3.40              8.50        110
# 3           136         mpfi  3.19    3.40              8.50        110
# 4           131         mpfi  3.13    3.40              8.30        140
# 5           108         mpfi  3.50    2.80              8.80        101
# 6           209         mpfi  3.62    3.39              8.00        182
# 7            90         2bbl  2.97    3.23              9.41         68
# 8            90         2bbl  2.97    3.23              9.40         68
# 9            98         mpfi  3.03    3.39              7.60        102
# 10           90         2bbl  2.97    3.23              9.40         68
# 11           98         mpfi  3.03    3.39              7.60        102
# 12          122         2bbl  3.34    3.46              8.50         88
# 13          110         1bbl  3.15    3.58              9.00         86
# 14           90         2bbl  3.03    3.11              9.60         70
# 15           91         2bbl  3.03    3.15              9.00         68
# 16           80         mpfi   NaN     NaN              9.40        135
# 17          122         2bbl  3.39    3.39              8.60         84
# 18          122         2bbl  3.39    3.39              8.60         84
# 19          122         2bbl  3.39    3.39              8.60         84
# 20          183          idi  3.58    3.64             21.50        123
# 21          234         mpfi  3.46    3.10              8.30        155
# 22          304         mpfi  3.80    3.35              8.00        184
# 23          140         mpfi  3.78    3.12              8.00        175
# 24          156         spdi  3.59    3.86              7.00        145
# 25          110         spdi  3.17    3.46              7.50        116
# 26           97         2bbl  3.15    3.29              9.40         69
# 27           97         2bbl  3.15    3.29              9.40         69
# 28          120         2bbl  3.33    3.47              8.50         97
# 29          181         mpfi  3.43    3.27              9.00        160
# 30          152          idi  3.70    3.52             21.00         95
# 31          120         mpfi  3.46    3.19              8.40         97
# 32           90         2bbl  2.97    3.23              9.40         68
# 33           90         2bbl  2.97    3.23              9.40         68
# 34          122         2bbl  3.35    3.46              8.50         88
# 35          121         mpfi  3.54    3.07              9.30        110
# 36          108         2bbl  3.62    2.64              9.00         82
# 37          108         mpfi  3.62    2.64              7.70        111
# 38           92         2bbl  3.05    3.03              9.00         62
# 39           92         2bbl  3.05    3.03              9.00         62
# 40          110          idi  3.27    3.35             22.50         56
# 41           98         2bbl  3.19    3.03              9.00         70
# 42          146         mpfi  3.62    3.50              9.30        116
# 43          110          idi  3.27    3.35             22.50         73
# 44          109         mpfi  3.19    3.40              9.00         85
# 45           97          idi  3.01    3.40             23.00         68
# 46          109         mpfi  3.19    3.40             10.00        100
# 47           97          idi  3.01    3.40             23.00         68
# 48          109         mpfi  3.19    3.40              9.00         88
# 49          141         mpfi  3.78    3.15              9.50        114
# 50          141         mpfi  3.78    3.15              9.50        114
# 51          141         mpfi  3.78    3.15              8.70        160
#
#     peak.rpm city.mpg  highway.mpg  Car_Price
# 0       5000       21           27        NaN
# 1       5500       18           22        NaN
# 2       5500       19           25        NaN
# 3       5500       19           25        NaN
# 4       5500       17           20        NaN
# 5       5800       23           29        NaN
# 6       5400       15           20        NaN
# 7       5500       37           41        NaN
# 8       5500       31           38        NaN
# 9       5500       24           30        NaN
# 10      5500       31           38        NaN
# 11      5500       24           30        NaN
# 12      5000       24           30        NaN
# 13      5800       27           33        NaN
# 14      5400       38           43        NaN
# 15      5000       30           31        NaN
# 16      6000       16           23        NaN
# 17      4800       26           32        NaN
# 18      4800       26           32        NaN
# 19      4800       26           32        NaN
# 20      4350       22           25        NaN
# 21      4750       16           18        NaN
# 22      4500       14           16        NaN
# 23      5000       19           24        NaN
# 24      5000       19           24        NaN
# 25      5500       23           30        NaN
# 26      5200       31           37        NaN
# 27      5200       31           37        NaN
# 28      5200       27           34        NaN
# 29      5200       19           25        NaN
# 30      4150       28           33        NaN
# 31      5000       19           24        NaN
# 32      5500       31           38        NaN
# 33      5500       31           38        NaN
# 34      5000       24           30        NaN
# 35      5250       21           28        NaN
# 36      4800       23           29        NaN
# 37      4800       23           23        NaN
# 38      4800       35           39        NaN
# 39      4800       27           32        NaN
# 40      4500       38           47        NaN
# 41      4800       28           34        NaN
# 42      4800       24           30        NaN
# 43      4500       30           33        NaN
# 44      5250       27           34        NaN
# 45      4500       37           42        NaN
# 46      5500       26           32        NaN
# 47      4500       33           38        NaN
# 48      5500       25           31        NaN
# 49      5400       23           28        NaN
# 50      5400       23           28        NaN
# 51      5300       19           25        NaN
#
# [52 rows x 26 columns]

# %%
data.hist(figsize=(12,10))
# Out:
# array([[<Axes: title={'center': 'symboling'}>,
#         <Axes: title={'center': 'normalized.losses'}>,
#         <Axes: title={'center': 'wheel.base'}>,
#         <Axes: title={'center': 'length'}>],
#        [<Axes: title={'center': 'width'}>,
#         <Axes: title={'center': 'height'}>,
#         <Axes: title={'center': 'curb.weight'}>,
#         <Axes: title={'center': 'engine.size'}>],
#        [<Axes: title={'center': 'bore'}>,
#         <Axes: title={'center': 'stroke'}>,
#         <Axes: title={'center': 'compression.ratio'}>,
#         <Axes: title={'center': 'horsepower'}>],
#        [<Axes: title={'center': 'peak.rpm'}>,
#         <Axes: title={'center': 'city.mpg'}>,
#         <Axes: title={'center': 'highway.mpg'}>,
#         <Axes: title={'center': 'Car_Price'}>]], dtype=object)

# %%
data.isna().sum()
# Out:
# symboling             0
# normalized.losses    12
# make                  0
# fuel.type             0
# aspiration            0
# num.of.doors          5
# body.style            0
# drive.wheels          0
# engine.location       4
# wheel.base            0
# length                0
# width                 0
# height                0
# curb.weight           0
# engine.type           0
# num.of.cylinders      1
# engine.size           0
# fuel.system           0
# bore                  1
# stroke                1
# compression.ratio     0
# horsepower            0
# peak.rpm              0
# city.mpg              0
# highway.mpg           0
# Car_Price            52
# dtype: int64

# %%
data.boxplot(figsize=(14,18))
# Out:
# <Axes: >

# %%
sns.pairplot(data)
# Out:
# C:\Users\my pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
X=data.iloc[:,:-1]

y=data.iloc[:,-1:]

# %%
X
# Out:
#     symboling  normalized.losses           make fuel.type aspiration  \
# 0           3                NaN    alfa-romero       gas        std
# 1           2              164.0           audi       gas        std
# 2           2                NaN           audi       gas        std
# 3           1                NaN           audi       gas        std
# 4           1              158.0           audi       gas      turbo
# 5           2              192.0            bmw       gas        std
# 6           0                NaN            bmw       gas        std
# 7           1              118.0          dodge       gas        std
# 8           1              118.0          dodge       gas        std
# 9           1              118.0          dodge       gas      turbo
# 10          1              148.0          dodge       gas        std
# 11          1              148.0          dodge       gas      turbo
# 12         -1              110.0          dodge       gas        std
# 13          0               85.0          honda       gas        std
# 14          1                NaN          isuzu       gas        std
# 15          1              104.0          mazda       gas        std
# 16          3              150.0          mazda       gas        std
# 17          1              129.0          mazda       gas        std
# 18          0              115.0          mazda       gas        std
# 19          0              115.0          mazda       gas        std
# 20         -1               93.0  mercedes-benz    diesel      turbo
# 21         -1                NaN  mercedes-benz       gas        std
# 22          1                NaN  mercedes-benz       gas        std
# 23          1                NaN        mercury       gas      turbo
# 24          3                NaN     mitsubishi       gas      turbo
# 25          1              125.0     mitsubishi       gas      turbo
# 26          1              128.0         nissan       gas        std
# 27          2              168.0         nissan       gas        std
# 28          0              106.0         nissan       gas        std
# 29          1              231.0         nissan       gas        std
# 30          0              161.0         peugot    diesel      turbo
# 31          0                NaN         peugot       gas        std
# 32          1              154.0       plymouth       gas        std
# 33          1              154.0       plymouth       gas        std
# 34         -1               74.0       plymouth       gas        std
# 35          2              104.0           saab       gas        std
# 36          0               85.0         subaru       gas        std
# 37          0               85.0         subaru       gas      turbo
# 38          1               87.0         toyota       gas        std
# 39          0               81.0         toyota       gas        std
# 40          0               91.0         toyota    diesel        std
# 41          0               91.0         toyota       gas        std
# 42          2              134.0         toyota       gas        std
# 43         -1               65.0         toyota    diesel      turbo
# 44          2               94.0     volkswagen       gas        std
# 45          2               94.0     volkswagen    diesel      turbo
# 46          2               94.0     volkswagen       gas        std
# 47          0                NaN     volkswagen    diesel      turbo
# 48          0                NaN     volkswagen       gas        std
# 49         -1               74.0          volvo       gas        std
# 50         -1               95.0          volvo       gas        std
# 51         -1               95.0          volvo       gas      turbo
#
#    num.of.doors   body.style drive.wheels engine.location  wheel.base  ...  \
# 0           two  convertible          rwd           front        88.6  ...
# 1          four        sedan          4wd             NaN        99.4  ...
# 2           two        sedan          fwd           front        99.8  ...
# 3          four        wagon          fwd           front       105.8  ...
# 4          four        sedan          fwd           front       105.8  ...
# 5           two        sedan          rwd           front       101.2  ...
# 6          four        sedan          rwd           front       110.0  ...
# 7           two    hatchback          fwd           front        93.7  ...
# 8           two    hatchback          fwd           front        93.7  ...
# 9           two    hatchback          fwd           front        93.7  ...
# 10         four        sedan          fwd             NaN        93.7  ...
# 11          NaN        sedan          fwd           front        93.7  ...
# 12         four        wagon          fwd           front       103.3  ...
# 13         four        sedan          fwd           front        96.5  ...
# 14          two        sedan          fwd           front        94.5  ...
# 15          two    hatchback          fwd           front        93.1  ...
# 16          two    hatchback          rwd           front        95.3  ...
# 17          NaN    hatchback          fwd           front        98.8  ...
# 18          NaN        sedan          fwd           front        98.8  ...
# 19         four        sedan          fwd             NaN        98.8  ...
# 20         four        wagon          rwd           front       110.0  ...
# 21         four        sedan          rwd           front       115.6  ...
# 22          two      hardtop          rwd             NaN       112.0  ...
# 23          two    hatchback          rwd           front       102.7  ...
# 24          two    hatchback          fwd           front        95.9  ...
# 25         four        sedan          fwd           front        96.3  ...
# 26          two    hatchback          fwd           front        94.5  ...
# 27          two      hardtop          fwd           front        95.1  ...
# 28         four        sedan          fwd           front        97.2  ...
# 29          two    hatchback          rwd           front        99.2  ...
# 30          NaN        sedan          rwd           front       107.9  ...
# 31         four        wagon          rwd           front       114.2  ...
# 32         four    hatchback          fwd           front        93.7  ...
# 33         four        sedan          fwd           front        93.7  ...
# 34         four        wagon          fwd           front       103.3  ...
# 35         four        sedan          fwd           front        99.1  ...
# 36         four        wagon          4wd           front        96.9  ...
# 37         four        wagon          4wd           front        96.9  ...
# 38          two    hatchback          fwd           front        95.7  ...
# 39         four        wagon          4wd           front        95.7  ...
# 40         four    hatchback          fwd           front        95.7  ...
# 41         four        sedan          fwd           front        95.7  ...
# 42          two    hatchback          rwd           front        98.4  ...
# 43         four        sedan          fwd           front       102.4  ...
# 44         four        sedan          fwd           front        97.3  ...
# 45         four        sedan          fwd           front        97.3  ...
# 46         four        sedan          fwd           front        97.3  ...
# 47         four        sedan          fwd           front       100.4  ...
# 48          NaN        wagon          fwd           front       100.4  ...
# 49         four        wagon          rwd           front       104.3  ...
# 50         four        sedan          rwd           front       109.1  ...
# 51         four        sedan          rwd           front       109.1  ...
#
#     num.of.cylinders  engine.size  fuel.system  bore stroke compression.ratio  \
# 0               four          130         mpfi  3.47   2.68              9.00
# 1               five          136         mpfi  3.19   3.40              8.00
# 2               five          136         mpfi  3.19   3.40              8.50
# 3               five          136         mpfi  3.19   3.40              8.50
# 4               five          131         mpfi  3.13   3.40              8.30
# 5               four          108         mpfi  3.50   2.80              8.80
# 6                six          209         mpfi  3.62   3.39              8.00
# 7               four           90         2bbl  2.97   3.23              9.41
# 8               four           90         2bbl  2.97   3.23              9.40
# 9               four           98         mpfi  3.03   3.39              7.60
# 10              four           90         2bbl  2.97   3.23              9.40
# 11              four           98         mpfi  3.03   3.39              7.60
# 12              four          122         2bbl  3.34   3.46              8.50
# 13              four          110         1bbl  3.15   3.58              9.00
# 14              four           90         2bbl  3.03   3.11              9.60
# 15              four           91         2bbl  3.03   3.15              9.00
# 16               two           80         mpfi   NaN    NaN              9.40
# 17              four          122         2bbl  3.39   3.39              8.60
# 18              four          122         2bbl  3.39   3.39              8.60
# 19              four          122         2bbl  3.39   3.39              8.60
# 20              five          183          idi  3.58   3.64             21.50
# 21             eight          234         mpfi  3.46   3.10              8.30
# 22             eight          304         mpfi  3.80   3.35              8.00
# 23              four          140         mpfi  3.78   3.12              8.00
# 24              four          156         spdi  3.59   3.86              7.00
# 25              four          110         spdi  3.17   3.46              7.50
# 26              four           97         2bbl  3.15   3.29              9.40
# 27              four           97         2bbl  3.15   3.29              9.40
# 28              four          120         2bbl  3.33   3.47              8.50
# 29               six          181         mpfi  3.43   3.27              9.00
# 30              four          152          idi  3.70   3.52             21.00
# 31              four          120         mpfi  3.46   3.19              8.40
# 32              four           90         2bbl  2.97   3.23              9.40
# 33              four           90         2bbl  2.97   3.23              9.40
# 34              four          122         2bbl  3.35   3.46              8.50
# 35              four          121         mpfi  3.54   3.07              9.30
# 36              four          108         2bbl  3.62   2.64              9.00
# 37              four          108         mpfi  3.62   2.64              7.70
# 38              four           92         2bbl  3.05   3.03              9.00
# 39              four           92         2bbl  3.05   3.03              9.00
# 40              four          110          idi  3.27   3.35             22.50
# 41              four           98         2bbl  3.19   3.03              9.00
# 42              four          146         mpfi  3.62   3.50              9.30
# 43              four          110          idi  3.27   3.35             22.50
# 44              four          109         mpfi  3.19   3.40              9.00
# 45              four           97          idi  3.01   3.40             23.00
# 46              four          109         mpfi  3.19   3.40             10.00
# 47              four           97          idi  3.01   3.40             23.00
# 48               NaN          109         mpfi  3.19   3.40              9.00
# 49              four          141         mpfi  3.78   3.15              9.50
# 50              four          141         mpfi  3.78   3.15              9.50
# 51              four          141         mpfi  3.78   3.15              8.70
#
#     horsepower peak.rpm  city.mpg  highway.mpg
# 0          111     5000        21           27
# 1          115     5500        18           22
# 2          110     5500        19           25
# 3          110     5500        19           25
# 4          140     5500        17           20
# 5          101     5800        23           29
# 6          182     5400        15           20
# 7           68     5500        37           41
# 8           68     5500        31           38
# 9          102     5500        24           30
# 10          68     5500        31           38
# 11         102     5500        24           30
# 12          88     5000        24           30
# 13          86     5800        27           33
# 14          70     5400        38           43
# 15          68     5000        30           31
# 16         135     6000        16           23
# 17          84     4800        26           32
# 18          84     4800        26           32
# 19          84     4800        26           32
# 20         123     4350        22           25
# 21         155     4750        16           18
# 22         184     4500        14           16
# 23         175     5000        19           24
# 24         145     5000        19           24
# 25         116     5500        23           30
# 26          69     5200        31           37
# 27          69     5200        31           37
# 28          97     5200        27           34
# 29         160     5200        19           25
# 30          95     4150        28           33
# 31          97     5000        19           24
# 32          68     5500        31           38
# 33          68     5500        31           38
# 34          88     5000        24           30
# 35         110     5250        21           28
# 36          82     4800        23           29
# 37         111     4800        23           23
# 38          62     4800        35           39
# 39          62     4800        27           32
# 40          56     4500        38           47
# 41          70     4800        28           34
# 42         116     4800        24           30
# 43          73     4500        30           33
# 44          85     5250        27           34
# 45          68     4500        37           42
# 46         100     5500        26           32
# 47          68     4500        33           38
# 48          88     5500        25           31
# 49         114     5400        23           28
# 50         114     5400        23           28
# 51         160     5300        19           25
#
# [52 rows x 25 columns]

# %%
X
# Out:
#     symboling  normalized.losses           make fuel.type aspiration  \
# 0           3                NaN    alfa-romero       gas        std
# 1           2              164.0           audi       gas        std
# 2           2                NaN           audi       gas        std
# 3           1                NaN           audi       gas        std
# 4           1              158.0           audi       gas      turbo
# 5           2              192.0            bmw       gas        std
# 6           0                NaN            bmw       gas        std
# 7           1              118.0          dodge       gas        std
# 8           1              118.0          dodge       gas        std
# 9           1              118.0          dodge       gas      turbo
# 10          1              148.0          dodge       gas        std
# 11          1              148.0          dodge       gas      turbo
# 12         -1              110.0          dodge       gas        std
# 13          0               85.0          honda       gas        std
# 14          1                NaN          isuzu       gas        std
# 15          1              104.0          mazda       gas        std
# 16          3              150.0          mazda       gas        std
# 17          1              129.0          mazda       gas        std
# 18          0              115.0          mazda       gas        std
# 19          0              115.0          mazda       gas        std
# 20         -1               93.0  mercedes-benz    diesel      turbo
# 21         -1                NaN  mercedes-benz       gas        std
# 22          1                NaN  mercedes-benz       gas        std
# 23          1                NaN        mercury       gas      turbo
# 24          3                NaN     mitsubishi       gas      turbo
# 25          1              125.0     mitsubishi       gas      turbo
# 26          1              128.0         nissan       gas        std
# 27          2              168.0         nissan       gas        std
# 28          0              106.0         nissan       gas        std
# 29          1              231.0         nissan       gas        std
# 30          0              161.0         peugot    diesel      turbo
# 31          0                NaN         peugot       gas        std
# 32          1              154.0       plymouth       gas        std
# 33          1              154.0       plymouth       gas        std
# 34         -1               74.0       plymouth       gas        std
# 35          2              104.0           saab       gas        std
# 36          0               85.0         subaru       gas        std
# 37          0               85.0         subaru       gas      turbo
# 38          1               87.0         toyota       gas        std
# 39          0               81.0         toyota       gas        std
# 40          0               91.0         toyota    diesel        std
# 41          0               91.0         toyota       gas        std
# 42          2              134.0         toyota       gas        std
# 43         -1               65.0         toyota    diesel      turbo
# 44          2               94.0     volkswagen       gas        std
# 45          2               94.0     volkswagen    diesel      turbo
# 46          2               94.0     volkswagen       gas        std
# 47          0                NaN     volkswagen    diesel      turbo
# 48          0                NaN     volkswagen       gas        std
# 49         -1               74.0          volvo       gas        std
# 50         -1               95.0          volvo       gas        std
# 51         -1               95.0          volvo       gas      turbo
#
#    num.of.doors   body.style drive.wheels engine.location  wheel.base  ...  \
# 0           two  convertible          rwd           front        88.6  ...
# 1          four        sedan          4wd             NaN        99.4  ...
# 2           two        sedan          fwd           front        99.8  ...
# 3          four        wagon          fwd           front       105.8  ...
# 4          four        sedan          fwd           front       105.8  ...
# 5           two        sedan          rwd           front       101.2  ...
# 6          four        sedan          rwd           front       110.0  ...
# 7           two    hatchback          fwd           front        93.7  ...
# 8           two    hatchback          fwd           front        93.7  ...
# 9           two    hatchback          fwd           front        93.7  ...
# 10         four        sedan          fwd             NaN        93.7  ...
# 11          NaN        sedan          fwd           front        93.7  ...
# 12         four        wagon          fwd           front       103.3  ...
# 13         four        sedan          fwd           front        96.5  ...
# 14          two        sedan          fwd           front        94.5  ...
# 15          two    hatchback          fwd           front        93.1  ...
# 16          two    hatchback          rwd           front        95.3  ...
# 17          NaN    hatchback          fwd           front        98.8  ...
# 18          NaN        sedan          fwd           front        98.8  ...
# 19         four        sedan          fwd             NaN        98.8  ...
# 20         four        wagon          rwd           front       110.0  ...
# 21         four        sedan          rwd           front       115.6  ...
# 22          two      hardtop          rwd             NaN       112.0  ...
# 23          two    hatchback          rwd           front       102.7  ...
# 24          two    hatchback          fwd           front        95.9  ...
# 25         four        sedan          fwd           front        96.3  ...
# 26          two    hatchback          fwd           front        94.5  ...
# 27          two      hardtop          fwd           front        95.1  ...
# 28         four        sedan          fwd           front        97.2  ...
# 29          two    hatchback          rwd           front        99.2  ...
# 30          NaN        sedan          rwd           front       107.9  ...
# 31         four        wagon          rwd           front       114.2  ...
# 32         four    hatchback          fwd           front        93.7  ...
# 33         four        sedan          fwd           front        93.7  ...
# 34         four        wagon          fwd           front       103.3  ...
# 35         four        sedan          fwd           front        99.1  ...
# 36         four        wagon          4wd           front        96.9  ...
# 37         four        wagon          4wd           front        96.9  ...
# 38          two    hatchback          fwd           front        95.7  ...
# 39         four        wagon          4wd           front        95.7  ...
# 40         four    hatchback          fwd           front        95.7  ...
# 41         four        sedan          fwd           front        95.7  ...
# 42          two    hatchback          rwd           front        98.4  ...
# 43         four        sedan          fwd           front       102.4  ...
# 44         four        sedan          fwd           front        97.3  ...
# 45         four        sedan          fwd           front        97.3  ...
# 46         four        sedan          fwd           front        97.3  ...
# 47         four        sedan          fwd           front       100.4  ...
# 48          NaN        wagon          fwd           front       100.4  ...
# 49         four        wagon          rwd           front       104.3  ...
# 50         four        sedan          rwd           front       109.1  ...
# 51         four        sedan          rwd           front       109.1  ...
#
#     num.of.cylinders  engine.size  fuel.system  bore stroke compression.ratio  \
# 0               four          130         mpfi  3.47   2.68              9.00
# 1               five          136         mpfi  3.19   3.40              8.00
# 2               five          136         mpfi  3.19   3.40              8.50
# 3               five          136         mpfi  3.19   3.40              8.50
# 4               five          131         mpfi  3.13   3.40              8.30
# 5               four          108         mpfi  3.50   2.80              8.80
# 6                six          209         mpfi  3.62   3.39              8.00
# 7               four           90         2bbl  2.97   3.23              9.41
# 8               four           90         2bbl  2.97   3.23              9.40
# 9               four           98         mpfi  3.03   3.39              7.60
# 10              four           90         2bbl  2.97   3.23              9.40
# 11              four           98         mpfi  3.03   3.39              7.60
# 12              four          122         2bbl  3.34   3.46              8.50
# 13              four          110         1bbl  3.15   3.58              9.00
# 14              four           90         2bbl  3.03   3.11              9.60
# 15              four           91         2bbl  3.03   3.15              9.00
# 16               two           80         mpfi   NaN    NaN              9.40
# 17              four          122         2bbl  3.39   3.39              8.60
# 18              four          122         2bbl  3.39   3.39              8.60
# 19              four          122         2bbl  3.39   3.39              8.60
# 20              five          183          idi  3.58   3.64             21.50
# 21             eight          234         mpfi  3.46   3.10              8.30
# 22             eight          304         mpfi  3.80   3.35              8.00
# 23              four          140         mpfi  3.78   3.12              8.00
# 24              four          156         spdi  3.59   3.86              7.00
# 25              four          110         spdi  3.17   3.46              7.50
# 26              four           97         2bbl  3.15   3.29              9.40
# 27              four           97         2bbl  3.15   3.29              9.40
# 28              four          120         2bbl  3.33   3.47              8.50
# 29               six          181         mpfi  3.43   3.27              9.00
# 30              four          152          idi  3.70   3.52             21.00
# 31              four          120         mpfi  3.46   3.19              8.40
# 32              four           90         2bbl  2.97   3.23              9.40
# 33              four           90         2bbl  2.97   3.23              9.40
# 34              four          122         2bbl  3.35   3.46              8.50
# 35              four          121         mpfi  3.54   3.07              9.30
# 36              four          108         2bbl  3.62   2.64              9.00
# 37              four          108         mpfi  3.62   2.64              7.70
# 38              four           92         2bbl  3.05   3.03              9.00
# 39              four           92         2bbl  3.05   3.03              9.00
# 40              four          110          idi  3.27   3.35             22.50
# 41              four           98         2bbl  3.19   3.03              9.00
# 42              four          146         mpfi  3.62   3.50              9.30
# 43              four          110          idi  3.27   3.35             22.50
# 44              four          109         mpfi  3.19   3.40              9.00
# 45              four           97          idi  3.01   3.40             23.00
# 46              four          109         mpfi  3.19   3.40             10.00
# 47              four           97          idi  3.01   3.40             23.00
# 48               NaN          109         mpfi  3.19   3.40              9.00
# 49              four          141         mpfi  3.78   3.15              9.50
# 50              four          141         mpfi  3.78   3.15              9.50
# 51              four          141         mpfi  3.78   3.15              8.70
#
#     horsepower peak.rpm  city.mpg  highway.mpg
# 0          111     5000        21           27
# 1          115     5500        18           22
# 2          110     5500        19           25
# 3          110     5500        19           25
# 4          140     5500        17           20
# 5          101     5800        23           29
# 6          182     5400        15           20
# 7           68     5500        37           41
# 8           68     5500        31           38
# 9          102     5500        24           30
# 10          68     5500        31           38
# 11         102     5500        24           30
# 12          88     5000        24           30
# 13          86     5800        27           33
# 14          70     5400        38           43
# 15          68     5000        30           31
# 16         135     6000        16           23
# 17          84     4800        26           32
# 18          84     4800        26           32
# 19          84     4800        26           32
# 20         123     4350        22           25
# 21         155     4750        16           18
# 22         184     4500        14           16
# 23         175     5000        19           24
# 24         145     5000        19           24
# 25         116     5500        23           30
# 26          69     5200        31           37
# 27          69     5200        31           37
# 28          97     5200        27           34
# 29         160     5200        19           25
# 30          95     4150        28           33
# 31          97     5000        19           24
# 32          68     5500        31           38
# 33          68     5500        31           38
# 34          88     5000        24           30
# 35         110     5250        21           28
# 36          82     4800        23           29
# 37         111     4800        23           23
# 38          62     4800        35           39
# 39          62     4800        27           32
# 40          56     4500        38           47
# 41          70     4800        28           34
# 42         116     4800        24           30
# 43          73     4500        30           33
# 44          85     5250        27           34
# 45          68     4500        37           42
# 46         100     5500        26           32
# 47          68     4500        33           38
# 48          88     5500        25           31
# 49         114     5400        23           28
# 50         114     5400        23           28
# 51         160     5300        19           25
#
# [52 rows x 25 columns]

# %%
y
# Out:
#     Car_Price
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# 30        NaN
# 31        NaN
# 32        NaN
# 33        NaN
# 34        NaN
# 35        NaN
# 36        NaN
# 37        NaN
# 38        NaN
# 39        NaN
# 40        NaN
# 41        NaN
# 42        NaN
# 43        NaN
# 44        NaN
# 45        NaN
# 46        NaN
# 47        NaN
# 48        NaN
# 49        NaN
# 50        NaN
# 51        NaN

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (41, 25)

# %%
y_train.shape
# Out:
# (41, 1)

# %%
x_test.shape
# Out:
# (11, 25)

# %%
y_test.shape
# Out:
# (11, 1)

# %%
from sklearn.linear_model import Ridge 
from sklearn.linear_model import Lasso

# %%
data.shape
# Out:
# (52, 26)

# %%
data.isna().sum()
# Out:
# symboling             0
# normalized.losses    12
# make                  0
# fuel.type             0
# aspiration            0
# num.of.doors          5
# body.style            0
# drive.wheels          0
# engine.location       4
# wheel.base            0
# length                0
# width                 0
# height                0
# curb.weight           0
# engine.type           0
# num.of.cylinders      1
# engine.size           0
# fuel.system           0
# bore                  1
# stroke                1
# compression.ratio     0
# horsepower            0
# peak.rpm              0
# city.mpg              0
# highway.mpg           0
# Car_Price            52
# dtype: int64

# %%
lasso_reg_1=Lasso(alpha=0.01)

# %%
lasso_reg_2=Lasso(alpha=0.001)

# %%
data.dropna()
# Out:
# Empty DataFrame
# Columns: [symboling, normalized.losses, make, fuel.type, aspiration, num.of.doors, body.style, drive.wheels, engine.location, wheel.base, length, width, height, curb.weight, engine.type, num.of.cylinders, engine.size, fuel.system, bore, stroke, compression.ratio, horsepower, peak.rpm, city.mpg, highway.mpg, Car_Price]
# Index: []
#
# [0 rows x 26 columns]

# %%
from sklearn.naive_bayes import GaussianNB
gauss_nb=GaussianNB()
gauss_nb.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 3
#       1 from sklearn.naive_bayes import GaussianNB
#       2 gauss_nb=GaussianNB()
# ----> 3 gauss_nb.fit(x_train,y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\naive_bayes.py:242, in GaussianNB.fit(self, X, y, sample_weight)
#     219 def fit(self, X, y, sample_weight=None):
#     220     """Fit Gaussian Naive Bayes according to X, y.
#     221
#     222     Parameters
#    (...)
#     240         Returns the instance itself.
#     241     """
# --> 242     y = self._validate_data(y=y)
#     243     return self._partial_fit(
#     244         X, y, np.unique(y), _refit=True, sample_weight=sample_weight
#     245     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:580, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     578     out = X
#     579 elif no_val_X and not no_val_y:
# --> 580     y = _check_y(y, **check_params)
#     581     out = y
#     582 else:
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1112, in _check_y(y, multi_output, y_numeric, estimator)
#    1110     estimator_name = _check_estimator_name(estimator)
#    1111     y = column_or_1d(y, warn=True)
# -> 1112     _assert_all_finite(y, input_name="y", estimator_name=estimator_name)
#    1113     _ensure_no_complex_data(y)
#    1114 if y_numeric and y.dtype.kind == "O":
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:146, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     124         if (
#     125             not allow_nan
#     126             and estimator_name
#    (...)
#     130             # Improve the error message on how to handle missing values in
#     131             # scikit-learn.
#     132             msg_err += (
#     133                 f"\n{estimator_name} does not accept missing values"
#     134                 " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     144                 "#estimators-that-handle-nan-values"
#     145             )
# --> 146         raise ValueError(msg_err)
#     148 # for object dtype data, we only check for NaNs (GH-13254)
#     149 elif X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input y contains NaN.
