# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1.Data Preparation

# %%
data = pd.read_csv('data_house.csv')
data
# Out:
#        Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0               0  7129300520  20141013T000000  221900.0         3       1.00
# 1               1  6414100192  20141209T000000  538000.0         3       2.25
# 2               2  5631500400  20150225T000000  180000.0         2       1.00
# 3               3  2487200875  20141209T000000  604000.0         4       3.00
# 4               4  1954400510  20150218T000000  510000.0         3       2.00
# ...           ...         ...              ...       ...       ...        ...
# 21608       21608   263000018  20140521T000000  360000.0         3       2.50
# 21609       21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610       21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611       21611   291310100  20150116T000000  400000.0         3       2.50
# 21612       21612  1523300157  20141015T000000  325000.0         2       0.75
#
# ...

# %%
data.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0         3       1.00
# 1           1  6414100192  20141209T000000  538000.0         3       2.25
# 2           2  5631500400  20150225T000000  180000.0         2       1.00
# 3           3  2487200875  20141209T000000  604000.0         4       3.00
# 4           4  1954400510  20150218T000000  510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data.tail()
# Out:
#        Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 21608       21608   263000018  20140521T000000  360000.0         3       2.50
# 21609       21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610       21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611       21611   291310100  20150116T000000  400000.0         3       2.50
# 21612       21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 21608         1530      1131     3.0           0  ...      8        1530
# 21609         2310      5813     2.0           0  ...      8        2310
# 21610         1020      1350     2.0           0  ...      7        1020
# 21611         1600      2388     2.0           0  ...      8        1600
# 21612         1020      1076     2.0           0  ...      7        1020
#
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0       0
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
data.describe()
# Out:
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21613.000000  21613.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.370842      2.114757
# std     6239.28002  2.876566e+09  3.671272e+05      0.930062      0.770163
# min        0.00000  1.000102e+06  7.500000e+04      0.000000      0.000000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# ...

# %%
data.head(1)
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0         3        1.0
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
#
# [1 rows x 22 columns]

# %%
x = data.iloc[:,:-1]
x.head(2)
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0         3       1.00
# 1           1  6414100192  20141209T000000  538000.0         3       2.25
#
#    sqft_living  sqft_lot  floors  waterfront  ...  condition  grade  \
# 0         1180      5650     1.0           0  ...          3      7
# 1         2570      7242     2.0           0  ...          3      7
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0        1180              0      1955             0    98178  47.5112
# 1        2170            400      1951          1991    98125  47.7210
#
#       long  sqft_living15
# 0 -122.257           1340
# 1 -122.319           1690
#
# [2 rows x 21 columns]

# %%
y = data.iloc[:,-1:]
y.head(2)
# Out:
#    sqft_lot15
# 0        5650
# 1        7639

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (21613, 22)

# %%
xtrain.shape
# Out:
# (21611, 21)

# %%
xtest
# Out:
#        Unnamed: 0          id             date      price  bedrooms  \
# 4131         4131  9516500100  20150418T000000   525000.0         3
# 17459       17459  3625700010  20140506T000000  1870000.0         5
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  condition  \
# 4131        1.75         1600      9579     1.0           0  ...          3
# 17459       4.00         4510     15175     2.0           0  ...          3
#
#        grade  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode  \
# 4131       8        1180            420      1977             0    98072
# 17459     10        4510              0      1969          2002    98040
#
#            lat     long  sqft_living15
# 4131   47.7662 -122.159           1750
# 17459  47.5309 -122.228           3510
#
# [2 rows x 21 columns]

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>],
#        [<Axes: title={'center': 'sqft_living'}>,
#         <Axes: title={'center': 'sqft_lot'}>,
#         <Axes: title={'center': 'floors'}>,
#         <Axes: title={'center': 'waterfront'}>,
#         <Axes: title={'center': 'view'}>],
#        [<Axes: title={'center': 'condition'}>,
#         <Axes: title={'center': 'grade'}>,
#         <Axes: title={'center': 'sqft_above'}>,
#         <Axes: title={'center': 'sqft_basement'}>,
#         <Axes: title={'center': 'yr_built'}>],
#        [<Axes: title={'center': 'yr_renovated'}>,
#         <Axes: title={'center': 'zipcode'}>,
#         <Axes: title={'center': 'lat'}>,
#         <Axes: title={'center': 'long'}>,
#         <Axes: title={'center': 'sqft_living15'}>],
# ...

# %%
a = data.iloc[:,:-1].values
b = data.iloc[:,-1].values
print(type(a),type(b))
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
b
# Out:
# array([5650, 7639, 8062, ..., 2007, 1287, 1357], dtype=int64)

# %%
a
# Out:
# array([[0, 7129300520, '20141013T000000', ..., 47.5112, -122.257, 1340],
#        [1, 6414100192, '20141209T000000', ..., 47.721, -122.319, 1690],
#        [2, 5631500400, '20150225T000000', ..., 47.7379, -122.233, 2720],
#        ...,
#        [21610, 1523300141, '20140623T000000', ..., 47.5944, -122.299,
#         1020],
#        [21611, 291310100, '20150116T000000', ..., 47.5345, -122.069,
#         1410],
#        [21612, 1523300157, '20141015T000000', ..., 47.5941, -122.299,
#         1020]], dtype=object)

# %% [markdown]
# # 2.Implement Simple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
print('house bedrooms..\n')
print()
lin_reg.fit(ytest,ytest)
print()
print('bedrooms')
print()
print('house started...\n')
ypred=lin_reg.predict(ytest)
print('Predicted total payment\n',ypred)
print('\n house also completed..\n')
# Out:
# house bedrooms..
#
#
#
# bedrooms
#
# house started...
#
# Predicted total payment
#  [[ 9829.]
#  [13500.]]
#
#  house also completed..

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression


X = np.array([1400, 1600, 1700, 1875, 1100, 1550, 2350, 2450, 1425, 1700])
y = np.array([245000, 312000, 279000, 308000, 199000, 219000, 405000, 324000, 319000, 255000])

model = LinearRegression()

model.fit(X.reshape(-1, 1), y)

predicted_prices = model.predict(X.reshape(-1, 1))

# %%
plt.scatter(X, y, label='house')
plt.plot(X, predicted_prices, color='red', label='Regression Line')
plt.xlabel('floors(Testdatset)')
plt.ylabel('House Price')
plt.legend()
plt.show()

# %%
ytest
# Out:
#        sqft_lot15
# 4131         9829
# 17459       13500

# %% [markdown]
# # 3.Evaluate the Simple Linear Regresion Model

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

print('Mean Squared Error: \t',mean_squared_error(ytest,ypred)) 
print()
print("RMSE:\t", np.sqrt(mean_squared_error(ytest,ypred))) 
print() 
print('Variance Score:\t',explained_variance_score (ytest,ypred))


print() 
print('R-Square:\t',r2_score (ytest,ypred))
# Out:
# Mean Squared Error: 	 1.6543612251060553e-24
#
# RMSE:	 1.2862197421537486e-12
#
# Variance Score:	 1.0
#
# R-Square:	 1.0

# %%
diff=ytest-ypred
diff
# Out:
#          sqft_lot15
# 4131  -1.818989e-12
# 17459  0.000000e+00

# %%
ytest
# Out:
#        sqft_lot15
# 4131         9829
# 17459       13500

# %%
import warnings
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score



data = pd.read_csv("data_house.csv")
x = data[['sqft_living', 'floors']]  # Features
y = data['price']  # Target variable


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=2, random_state=3)

model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared (R2) Score: {r2}")


new_data = np.array([[2, 3]])  
predicted_price = model.predict(new_data)
print(f"Predicted house price: ${predicted_price[0]}")
# Out:
# Mean Squared Error: 217543561202.1416
# R-squared (R2) Score: 0.5189816366227298
# Predicted house price: $-30348.551854862642
# C:\Users\my pc\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.2,random_state=1)

# %%
df=pd.read_csv('data_house.csv')
df.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0         3       1.00
# 1           1  6414100192  20141209T000000  538000.0         3       2.25
# 2           2  5631500400  20150225T000000  180000.0         2       1.00
# 3           3  2487200875  20141209T000000  604000.0         4       3.00
# 4           4  1954400510  20150218T000000  510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df =df.fillna(method='bfill')
df.isna().sum()
# Out:
# Unnamed: 0       0
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
x=data.iloc[:,:-1]
x.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0         3       1.00
# 1           1  6414100192  20141209T000000  538000.0         3       2.25
# 2           2  5631500400  20150225T000000  180000.0         2       1.00
# 3           3  2487200875  20141209T000000  604000.0         4       3.00
# 4           4  1954400510  20150218T000000  510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  condition  grade  \
# 0         1180      5650     1.0           0  ...          3      7
# 1         2570      7242     2.0           0  ...          3      7
# 2          770     10000     1.0           0  ...          3      6
# 3         1960      5000     1.0           0  ...          5      7
# 4         1680      8080     1.0           0  ...          3      8
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# ...

# %%
y=data.iloc[:,-1:]
y.head()
# Out:
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.2,random_state=1)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['date']=le.fit_transform(data['date'])
data.head()
# Out:
#    Unnamed: 0          id  date     price  bedrooms  bathrooms  sqft_living  \
# 0           0  7129300520   164  221900.0         3       1.00         1180
# 1           1  6414100192   220  538000.0         3       2.25         2570
# 2           2  5631500400   290  180000.0         2       1.00          770
# 3           3  2487200875   220  604000.0         4       3.00         1960
# 4           4  1954400510   283  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  ...  grade  sqft_above  sqft_basement  \
# 0      5650       0           0  ...      7        1180              0
# 1      7242       2           0  ...      7        2170            400
# 2     10000       0           0  ...      6         770              0
# 3      5000       0           0  ...      7        1050            910
# 4      8080       0           0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data_house.csv')
data
# Out:
#        Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0               0  7129300520  20141013T000000  221900.0         3       1.00
# 1               1  6414100192  20141209T000000  538000.0         3       2.25
# 2               2  5631500400  20150225T000000  180000.0         2       1.00
# 3               3  2487200875  20141209T000000  604000.0         4       3.00
# 4               4  1954400510  20150218T000000  510000.0         3       2.00
# ...           ...         ...              ...       ...       ...        ...
# 21608       21608   263000018  20140521T000000  360000.0         3       2.50
# 21609       21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610       21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611       21611   291310100  20150116T000000  400000.0         3       2.50
# 21612       21612  1523300157  20141015T000000  325000.0         2       0.75
#
# ...

# %%
x=data.iloc[:,:-1]
x.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0         3       1.00
# 1           1  6414100192  20141209T000000  538000.0         3       2.25
# 2           2  5631500400  20150225T000000  180000.0         2       1.00
# 3           3  2487200875  20141209T000000  604000.0         4       3.00
# 4           4  1954400510  20150218T000000  510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  condition  grade  \
# 0         1180      5650     1.0           0  ...          3      7
# 1         2570      7242     2.0           0  ...          3      7
# 2          770     10000     1.0           0  ...          3      6
# 3         1960      5000     1.0           0  ...          5      7
# 4         1680      8080     1.0           0  ...          3      8
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# ...

# %%
y=data.iloc[:,-1:]
y.head()
# Out:
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
mul_reg=LinearRegression()

mul_reg.fit(ytrain,ytrain)

ypred=mul_reg.predict(ytest)

from sklearn.metrics import mean_squared_error,r2_score
print()
print('RMSE: ',np.sqrt(mean_squared_error(ytest,ypred)))
print()
print('R-square: ',r2_score(ytest,ypred))
print()
# Out:
# RMSE:  4.298664193378033e-12
#
# R-square:  1.0

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

print('Mean Squar Error: \t',mean_squared_error(ytest,ypred))
print()
print('RMSE:\t',np.sqrt(mean_squared_error(ytest,ypred)))
print()
print('Variance Score:\t',explained_variance_score(ytest,ypred))

print()
print('R-Sqaure:\t',r2_score(ytest,ypred))
# Out:
# Mean Squar Error: 	 1.847851384743042e-23
#
# RMSE:	 4.298664193378033e-12
#
# Variance Score:	 1.0
#
# R-Sqaure:	 1.0
